# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
import math

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split

# %%
file1 = pd.read_csv('marketing_customer_analysis.csv')

# %%
file1.head()
# Out:
#   Customer       State  Customer Lifetime Value Response  Coverage Education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
#
#   Effective To Date EmploymentStatus Gender  Income  ...  \
# 0           2/24/11         Employed      F   56274  ...
# 1           1/31/11       Unemployed      F       0  ...
# 2           2/19/11         Employed      F   48767  ...
# 3           1/20/11       Unemployed      M       0  ...
# 4            2/3/11         Employed      M   43836  ...
#
#   Months Since Policy Inception Number of Open Complaints  Number of Policies  \
# ...

# %%
columns = list(file1.columns)
print(columns)
# Out:
# ['Customer', 'State', 'Customer Lifetime Value', 'Response', 'Coverage', 'Education', 'Effective To Date', 'EmploymentStatus', 'Gender', 'Income', 'Location Code', 'Marital Status', 'Monthly Premium Auto', 'Months Since Last Claim', 'Months Since Policy Inception', 'Number of Open Complaints', 'Number of Policies', 'Policy Type', 'Policy', 'Renew Offer Type', 'Sales Channel', 'Total Claim Amount', 'Vehicle Class', 'Vehicle Size']

# %%
columns_lower = list(map(lambda x: x.lower(),columns))

# %%
columns_lower_underscore = list(map(lambda x: x.replace(' ','_'),columns_lower))
print(columns_lower_underscore)
# Out:
# ['customer', 'state', 'customer_lifetime_value', 'response', 'coverage', 'education', 'effective_to_date', 'employmentstatus', 'gender', 'income', 'location_code', 'marital_status', 'monthly_premium_auto', 'months_since_last_claim', 'months_since_policy_inception', 'number_of_open_complaints', 'number_of_policies', 'policy_type', 'policy', 'renew_offer_type', 'sales_channel', 'total_claim_amount', 'vehicle_class', 'vehicle_size']

# %%
file1.columns = columns_lower_underscore
file1.head()
# Out:
#   customer       state  customer_lifetime_value response  coverage education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
#
#   effective_to_date employmentstatus gender  income  ...  \
# 0           2/24/11         Employed      F   56274  ...
# 1           1/31/11       Unemployed      F       0  ...
# 2           2/19/11         Employed      F   48767  ...
# 3           1/20/11       Unemployed      M       0  ...
# 4            2/3/11         Employed      M   43836  ...
#
#   months_since_policy_inception number_of_open_complaints  number_of_policies  \
# ...

# %%
data = pd.DataFrame(file1)

# %%
data['date'] = pd.to_datetime(data['effective_to_date'],errors = 'coerce')

# %%
data['month'] = list(map(lambda x: x.month, data['date']))

# %%
data.head()
# Out:
#   customer       state  customer_lifetime_value response  coverage education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
#
#   effective_to_date employmentstatus gender  income  ... number_of_policies  \
# 0           2/24/11         Employed      F   56274  ...                  1
# 1           1/31/11       Unemployed      F       0  ...                  8
# 2           2/19/11         Employed      F   48767  ...                  2
# 3           1/20/11       Unemployed      M       0  ...                  7
# 4            2/3/11         Employed      M   43836  ...                  1
#
# ...

# %%
#attempting to split/slice x and y
#x = data.iloc[:, data.columns != 'total_claim_amount']
x = data.iloc[:,0:14] + data.iloc[:,15:]
print(x)
# Out:
#       coverage  customer  customer_lifetime_value  date  education  \
# 0          NaN       NaN                      NaN   NaN        NaN
# 1          NaN       NaN                      NaN   NaN        NaN
# 2          NaN       NaN                      NaN   NaN        NaN
# 3          NaN       NaN                      NaN   NaN        NaN
# 4          NaN       NaN                      NaN   NaN        NaN
# ...        ...       ...                      ...   ...        ...
# 9129       NaN       NaN                      NaN   NaN        NaN
# 9130       NaN       NaN                      NaN   NaN        NaN
# 9131       NaN       NaN                      NaN   NaN        NaN
# 9132       NaN       NaN                      NaN   NaN        NaN
# 9133       NaN       NaN                      NaN   NaN        NaN
#
#       effective_to_date  employmentstatus  gender  income  location_code  ...  \
# 0                   NaN               NaN     NaN     NaN            NaN  ...
# ...

# %%
#normalize
from sklearn.preprocessing import Normalizer
transformer = Normalizer().fit(data)
x_normalized = transformer.transform(data)
print(x_normalized.shape)
# pd.DataFrame(x_normalized)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-49-5b6cb4cbb927> in <module>
#       1 #normalize
#       2 from sklearn.preprocessing import Normalizer
# ----> 3 transformer = Normalizer().fit(data)
#       4 x_normalized = transformer.transform(data)
#       5 print(x_normalized.shape)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/preprocessing/_data.py in fit(self, X, y)
#    1822         X : array-like
#    1823         """
# -> 1824         self._validate_data(X, accept_sparse='csr')
#    1825         return self
#    1826
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     418                     f"requires y to be passed, but the target y is None."
#     419                 )
# --> 420             X = check_array(X, **check_params)
# ...
